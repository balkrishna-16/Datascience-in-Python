# %%
import modules_day8
print(dir(modules_day8))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import modules_day8
#       2 print(dir(modules_day8))
#
# ModuleNotFoundError: No module named 'modules_day8'
