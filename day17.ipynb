# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in .\.venv\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in .\.venv\Lib\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in .\.venv\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in .\.venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in .\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# %%
#dataset
data = {
    "Experience": [1, 2, 3, 4, 5,6,7],
    "Salary": [20000, 25000, 30000, 35000, 40000, 45000, 50000]
}
df = pd.DataFrame(data)
df
# Out:
#    Experience  Salary
# 0           1   20000
# 1           2   25000
# 2           3   30000
# 3           4   35000
# 4           5   40000
# 5           6   45000
# 6           7   50000

# %%
x = df[["Experience"]]
y = df["Salary"]
# model = LinearRegression()
model = LogisticRegression()
model.fit(x, y)
# Out:
# LogisticRegression()

# %%
#prediction
predicted_salary = model.predict([[8]])
# print(predicted_salary)
# Out:
# c:\Users\DELL\OneDrive\Desktop\Python Datascience\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
#scatterplot
plt.scatter(x,y)
plt.plot(x, model.predict(x), color='red')
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Regression Line")
# Out:
# Text(0.5, 1.0, 'Regression Line')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
iris = load_iris()
df = pd.DataFrame(data=iris.data,columns=iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#adding target column
df["target"] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
#mapping target values to species names
df["species"]= df["target"].map({0: "setosa", 1: "versicolor", 2: "virginica"})
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target    species
# 0         0     setosa
# 1         0     setosa
# 2         0     setosa
# 3         0     setosa
# 4         0     setosa
# ..      ...        ...
# 145       2  virginica
# 146       2  virginica
# 147       2  virginica
# 148       2  virginica
# 149       2  virginica
#
# [150 rows x 6 columns]

# %%
print("First 5 rows of the dataset:")
df.head()
print("Shape of the dataset:")
df.shape
print(df['species'].value_counts())
# Out:
# First 5 rows of the dataset:
# Shape of the dataset:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
#Visualization
plt.figure(figsize=(10,6))
plt.scatter(df["petal length (cm)"], df["petal width (cm)"], c=df["target"], cmap="viridis")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.title("Iris Dataset: Petal Length vs Petal Width")
plt.show()

# %%
x= df[iris.feature_names]
y = df["target"]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#splitting the data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=42)

# %%
#Training the model
model = LogisticRegression(max_iter=200)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
#predicted_salary
y_pred = model.predict(x_test)
print("Predicted labels:", y_pred)
# Out:
# Predicted labels: [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0]

# %%
print("Supervised learning results:", y_pred)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Supervised learning results: [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0]
# Accuracy: 1.0

# %%
print("\n Classification Report:\n", classification_report(y_test, y_pred))
# Out:
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
