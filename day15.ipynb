# %%
# !pip install matplotlib

# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.9

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv("customers-100.csv")
df = pd.read_csv("Mobile_data.csv")
# df = pd.read_csv("brother.csv.csv")

print(df.head())
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422        1690        1529.0         1819.0
# 1  Android         323        1803        1659.0         2489.0
# 2  Android         299        1803        1659.0         2489.0
# 3  Android         287        1803        1659.0         2489.0
# 4  Android        1047        1999           NaN            NaN
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36         5.00          8.0        2000.0       20-Oct
# ...

# %%
# plt.bar(df['OS'], df['Property'])
# plt.xlabel("OS")
# plt.ylabel("Property")
# plt.title("OS vs Property")
# plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(27, 10))
plt.xlabel("brand name")
plt.ylabel("best price")
plt.title("brand name vs best price")
plt.bar(df['brand_name'], df['best_price'])


plt.xticks(rotation=45)  
plt.show()

# %%
plt.title("Sales Trend")
plt.xlabel("operating system")
plt.ylabel("popularity")
# plt.hist(df['range='], bins=10)
# Out:
# Text(0, 0.5, 'popularity')

# %%
plt.figure(figsize=(10, 8))
df['os'].value_counts().plot(kind='pie')
plt.show()

# %%
df['brand_name'].value_counts().plot(kind='hist', bins=12)
# Out:
# <Axes: ylabel='Frequency'>

# %%
histogram = df['popularity'].hist(bins=10)

# %%
plt.figure(figsize=(25, 6))
histogram = df['brand_name'].hist(bins=7)
plt.show()

# %%
plt.plot(df['highest_price'], df['lowest_price'], marker='o')

# %%
plt.scatter(df['highest_price'], df['lowest_price'])

# %%
import matplotlib.pyplot as plt
x = [-100, -200, 0, 120, 220]
y = [100, 400, 0, 100, 400]
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [-100, -200, 0, 120, 220]
y = [100, 400, 0, 100, 400]
z = [150, 450, 0, 200, 600]
plt.plot(x, color='red', marker='o', linestyle='--')
#plt.plot(y, color='blue', marker='o', linestyle='--')
plt.plot(z, color='green', marker='o', linestyle='--')
plt.plot(y, marker='D', ms=10, mfc='yellow', mec='red', mew=2)
plt.title("Sample Line Plot")
plt.xlabel("X Axis Label")
plt.ylabel("Y Axis Label")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x, y)
plt.show()
