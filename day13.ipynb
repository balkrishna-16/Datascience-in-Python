# %% [markdown]
# # Pandas

# %%
# !pip install pandas

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.2

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\DELL\OneDrive\Desktop\Python Datascience\.venv\Scripts\python.exe

# %%
import pandas as pd

# Data create
data = {
    "Name": ["Ram", "Shyam", "Hari"],
    "Age": [20, 22, 21],
    "Marks": [80, 75, 90]
}

# DataFrame
df = pd.DataFrame(data)

# Data print
print("Full Data:")
print(df)

# First 2 rows
print("\nFirst 2 rows:")
print(df.head(2))

# Mean (average)
print("\nAverage Marks:")
print(df["Marks"].mean())

# Max marks
print("\nHighest Marks:")
print(df["Marks"].max())
# Out:
# Full Data:
#     Name  Age  Marks
# 0    Ram   20     80
# 1  Shyam   22     75
# 2   Hari   21     90
#
# First 2 rows:
#     Name  Age  Marks
# 0    Ram   20     80
# 1  Shyam   22     75
#
# Average Marks:
# 81.66666666666667
#
# Highest Marks:
# 90

# %%
import pandas as pd
data = ["apple", "ball", "cat"]
result = pd.Series(data)
print(result)
# Out:
# 0    apple
# 1     ball
# 2      cat
# dtype: str

# %%
data =  {"Name": ["Ram", "Shyam", "Hari"],
    "Age": [20, 22, 21],
    "Marks": [80, 75, 90]
    }
# dataframe
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Marks
# 0    Ram   20     80
# 1  Shyam   22     75
# 2   Hari   21     90

# %%
data = {"Employees":["Balkrishna", "Gita","Nawaraj", "Raju","Anshu"],
        "designation": ["Manager","staff","Assistance","मिस्तिरी","बेपारी"],
        "salary": ["130000","50000","25000","1200","5000"]
        }
df = pd.DataFrame(data)
# print(df)
df.head()
# df.head(2)
# df["Employees"].max()
# Out:
#     Employees designation  salary
# 0  Balkrishna     Manager  130000
# 1        Gita       staff   50000
# 2     Nawaraj  Assistance   25000
# 3        Raju    मिस्तिरी    1200
# 4       Anshu      बेपारी    5000

# %%
df = pd.read_csv("customers-100.csv")
# print(df)
# df.head()
df.head(500)
# df["First Name"].max()
# df.loc()
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    str
#  2   First Name         100 non-null    str
#  3   Last Name          100 non-null    str
#  4   Company            100 non-null    str
#  5   City               100 non-null    str
#  6   Country            100 non-null    str
#  7   Phone 1            100 non-null    str
#  8   Phone 2            100 non-null    str
#  9   Email              100 non-null    str
#  10  Subscription Date  100 non-null    str
#  11  Website            100 non-null    str
# dtypes: int64(1), str(11)
# memory usage: 9.5 KB

# %%
df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df = pd.read_csv("Mobile_data.csv")
# print(df)
# df.head(100)
# df["brand_name"].max()
# df["brand_name"].unique()
# df.describe()
# df.columns
# df["Unnamed: 0"].drop()
df.drop(columns="Unnamed: 0", inplace=True)
# df.drop(columns="Unnamed: 0", inplace=False)
df.isnull().sum()

# df.head()
# df.columns
# df[["brand_name"] == "KAIoS"]
# df[["brand_name"] == "Vivo"]
# Out:
# brand_name          0
# model_name          0
# os                197
# popularity          0
# best_price          0
# lowest_price      260
# highest_price     260
# sellers_amount      0
# screen_size         2
# memory_size       112
# battery_size       10
# release_date        0
# dtype: int64

# %% [markdown]
# # Example Workdown

# %%
# df.isnull().sum()
# df.duplicated().sum()
df.drop_duplicates()
# df.groupby('brand_name')
# df['highest_price'] = df['highest_price']
# print("mean is ", x)data
# Out:
#         brand_name                                    model_name       os  \
# 0          ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)  Android
# 1          ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  Android
# 2          ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  Android
# 3          ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  Android
# 4            Nokia                           1.3 1/16GB Charcoal  Android
# ...            ...                                           ...      ...
# 1219         Apple               iPhone XS Max 64GB Gold (MT522)      iOS
# 1220         Apple      iPhone XS Max Dual Sim 64GB Gold (MT732)      iOS
# 1221        HUAWEI              nova 5T 6/128GB Black (51094MEU)  Android
# 1222           ZTE              nubia Red Magic 5G 8/128GB Black  Android
# 1223  Sigma mobile                             x-style 35 Screen      NaN
#
#       popularity  best_price  lowest_price  highest_price  sellers_amount  \
# ...

# %%
# Series
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
# DataFrame
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#use a list of indexes:
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
